# %%
import random
print("welcome to number guessing game")
# choose number betwwen 1 to 100

secret_number =random.randint(1,100)
attempt = 0 

while True:
           try:
               guess = int(input("Enter your guess(1-100"))
               attempt+=1

               if guess<1 or guess>100:
                    print("Plase enter number between 1 to 100")
                    continue
               
               if guess<secret_number:
                    print("To low ! please try agian")

               elif guess >secret_number:
                     print("To High! please try agian ")

               else:
                     print(f"correct ! you guessed the number in {attempt} attempts")
                     break

           except valueError:
                print("Invalid input ! Please enter a valid number ")
# Out:
# welcome to number guessing game
# Enter your guess(1-100 25
# To low ! please try agian
# Enter your guess(1-100 35
# To low ! please try agian
# Enter your guess(1-100 45
# To low ! please try agian
# Enter your guess(1-100 55
# To low ! please try agian
# Enter your guess(1-100 75
# To High! please try agian
# Enter your guess(1-100 60
# To low ! please try agian
# Enter your guess(1-100 65
# To low ! please try agian
# Enter your guess(1-100 68
# To High! please try agian
# Enter your guess(1-100 66
# To low ! please try agian
# Enter your guess(1-100 67
# correct ! you guessed the number in 10 attempts
